# %%
# encoding=utf-8
import os
import math
import re

import numpy as np
import pandas as pd

# %%
csv_filename = 'ruby_furigana.csv'
pd_df = pd.read_csv(csv_filename, encoding='utf-8')
pd_df.head()
# Out:
#   word                        html_ruby        ローマ字               meaning
# 0  一年生  一<rt>いち</rt>年<rt>ねん</rt>生<rt>せい  ichinensei  first year; freshman
# 1   名前          名<rt>な</rt>前<rt>まえ</rt>       namae                  name
# 2   小学        小<rt>しょう</rt>学<rt>がく</rt>    shougaku     elementary school
# 3   中学        中<rt>ちゅう</rt>学<rt>がく</rt>    chuugaku         middle school
# 4   高校         高<rt>こう</rt>校<rt>こう</rt>      koukou           high school

# %%
sorted_df = pd_df.sort_values(['word'])
sorted_df
# Out:
#      word                             html_ruby        ローマ字  \
# 31     ご飯                ご<rt></rt>飯<rt>はん</rt>       gohan
# 0     一年生       一<rt>いち</rt>年<rt>ねん</rt>生<rt>せい  ichinensei
# 7     三年生  三<rt>さん</rt>年<rt>ねん</rt>生<rt>せい</rt>   sannensei
# 3      中学             中<rt>ちゅう</rt>学<rt>がく</rt>    chuugaku
# 46     乗る                          乗<rt>の</rt>る        noru
# 6     二年生   二<rt>に</rt>年<rt>ねん</rt>生<rt>せい</rt>    ninensei
# 51     仕事               仕<rt>し</rt>事<rt>ごと</rt>     shigoto
# 42     会う                          会<rt>あ</rt>う          au
# 21     元気               元<rt>げん</rt>気<rt>き</rt>       genki
# 48      前                          前<rt>まえ</rt>         mae
# 38     友達              友<rt>とも</rt>達<rt>だち</rt>   tomodachi
# 1      名前               名<rt>な</rt>前<rt>まえ</rt>       namae
# 8     四年生   四<rt>よ</rt>年<rt>ねん</rt>生<rt>せい</rt>    yonensei
# 26    大好き              大<rt>だい</rt>好<rt>す</rt>き     daisuki
# 5      大学              大<rt>だい</rt>学<rt>がく</rt>     daigaku
# ...

# %%
out_filename = 'sorted_furigana.csv'
# sorted_df.to_csv(out_filename, encoding='utf-8', index=False)
sorted_df.to_csv(csv_filename, encoding='utf-8', index=False)
